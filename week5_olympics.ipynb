# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('olympics.csv')

# %%
df.head()
# Out:
#                 edition  edition_id country_noc_x      sport            event  \
# 0  1908 Summer Olympics           5           ANZ  Athletics  100 metres, Men
# 1  1908 Summer Olympics           5           ANZ  Athletics  400 metres, Men
# 2  1908 Summer Olympics           5           ANZ  Athletics  800 metres, Men
# 3  1908 Summer Olympics           5           ANZ  Athletics  800 metres, Men
# 4  1908 Summer Olympics           5           ANZ  Athletics  800 metres, Men
#
#    result_id          athlete  athlete_id        pos medal  isTeamSport  \
# 0      56265  Ernest Hutcheon       64710        DNS   NaN        False
# 1      56313     Henry Murray       64756        DNS   NaN        False
# 2      56338    Harvey Sutton       64808  3 h8 r1/2   NaN        False
# 3      56338      Guy Haskins      922519        DNS   NaN        False
# 4      56338     Joseph Lynch       64735        DNS   NaN        False
#
# ...

# %%
#Q1 
#no suitable index so have used the default

# %%
#Q2
#datatypes of the columns
df.dtypes
# Out:
# edition           object
# edition_id         int64
# country_noc_x     object
# sport             object
# event             object
# result_id          int64
# athlete           object
# athlete_id         int64
# pos               object
# medal             object
# isTeamSport         bool
# name              object
# sex               object
# born              object
# height           float64
# weight            object
# country           object
# country_noc_y     object
# description       object
# special_notes     object
# dtype: object

# %%
#Q3
#most common values in each column
df.describe(include = 'all')
#this does not tell us alot as most datatypes are objects
# Out:
#                      edition     edition_id country_noc_x      sport  \
# count                 316834  316834.000000        316834     316834
# unique                    55            NaN           231        112
# top     2020 Summer Olympics            NaN           USA  Athletics
# freq                   14816            NaN         23700      47792
# mean                     NaN      30.038815           NaN        NaN
# std                      NaN      18.430840           NaN        NaN
# min                      NaN       1.000000           NaN        NaN
# 25%                      NaN      16.000000           NaN        NaN
# 50%                      NaN      24.000000           NaN        NaN
# 75%                      NaN      49.000000           NaN        NaN
# max                      NaN      62.000000           NaN        NaN
#
#                 event     result_id        athlete    athlete_id     pos  \
# ...

# %%
#the below works to change the datatype of edition id e.g. from a string to int64
df['edition_id'] = df['edition_id'].astype(np.int64)
#but you get an error trying to change sex (object) to a integer

# %%
df.dtypes
# Out:
# edition           object
# edition_id         int64
# country_noc_x     object
# sport             object
# event             object
# result_id          int64
# athlete           object
# athlete_id         int64
# pos               object
# medal             object
# isTeamSport         bool
# name              object
# sex               object
# born              object
# height           float64
# weight            object
# country           object
# country_noc_y     object
# description       object
# special_notes     object
# dtype: object

# %%
#so the most common values for the columns with data types int64 are visable in the mean

# %%
#you could do mode for the middle of the dataset for the object/string variables
#but this is not really that helpful
df.mode()
# Out:
#                                              edition  edition_id  \
# 0  <pandas.core.strings.StringMethods object at 0...          61
#
#   country_noc_x      sport          event  result_id        athlete  \
# 0           USA  Athletics  Football, Men      33688  Tait McKenzie
#
#    athlete_id pos medal  isTeamSport           name   sex  born  height  \
# 0      920191   1  Gold        False  Tait McKenzie  Male  1931   180.0
#
#   weight         country country_noc_y description  \
# 0     70   United States           USA           .
#
#                                        special_notes
# 0  Listed in Olympians Who Received the Italian O...

# %%
#it would still be good to know whether there are more males or females or what the most common sport is for example
df['female'] = df['sex'] == 'female'

# %%
df.head()
# Out:
#                                              edition  edition_id  \
# 0  <pandas.core.strings.StringMethods object at 0...           5
# 1  <pandas.core.strings.StringMethods object at 0...           5
# 2  <pandas.core.strings.StringMethods object at 0...           5
# 3  <pandas.core.strings.StringMethods object at 0...           5
# 4  <pandas.core.strings.StringMethods object at 0...           5
#
#   country_noc_x      sport            event  result_id          athlete  \
# 0           ANZ  Athletics  100 metres, Men      56265  Ernest Hutcheon
# 1           ANZ  Athletics  400 metres, Men      56313     Henry Murray
# 2           ANZ  Athletics  800 metres, Men      56338    Harvey Sutton
# 3           ANZ  Athletics  800 metres, Men      56338      Guy Haskins
# 4           ANZ  Athletics  800 metres, Men      56338     Joseph Lynch
#
#    athlete_id        pos medal  ...             name   sex              born  \
# ...
